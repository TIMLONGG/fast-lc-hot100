# %%
# fast hot100
# 2026-04-09

# %% [markdown]
# # Review

# %%
# 15. 三数之和
# M
# 4

class Solution:
    def threeSum(self, nums: list[int]) -> list[list[int]]:
        # 2026-04-09
        # Time 6:56
        nums.sort()
        n = len(nums)
        ans = []
        for i in range(n-2):
            if i > 0 and nums[i] == nums[i-1]:
                continue

            if nums[i] + nums[i+1] + nums[i+2] > 0:
                break
            if nums[i] + nums[-2] + nums[-1] < 0:  
                continue

            l, r = i + 1, n - 1
            while l < r:
                s = nums[i] + nums[l] + nums[r]
                if s < 0:
                    l += 1
                elif s > 0:
                    r -= 1
                else:
                    ans.append([nums[i], nums[l], nums[r]])
                    l += 1
                    r -= 1
                    while l < r and nums[l] == nums[l-1]:
                        l += 1
                    while l < r and nums[r] == nums[r+1]:
                        r -= 1
        
        return ans

# else后面的l+=1 r-=1 开始忘加了 导致报越界错误

# %%
# 189. 轮转数组
# M
# 5 4 4

class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        # 方法1 使用O(n)额外空间
        # Time 2:28
        n = len(nums)
        ans = [0] * n

        for i in range(n):
            ans[(i+k)%n] = nums[i]
        
        for i in range(n):
            nums[i] = ans[i]

class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        # 方法2 环形替换
        # Time 6:00
        n = len(nums)
        cnt = gcd(n, k)
 
        k %= n  # 这里优化不要忘了

        for start in range(cnt):
            i = start
            prev = nums[start]
            while True:
                nxt = (i + k) % n
                prev, nums[nxt] = nums[nxt], prev
                i = nxt
                if i == start:
                    break


class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        # 方法3 翻转数组
        # Time 3:21
        
        def reverse(l, r):
            # 闭区间
            while l < r:
                nums[l], nums[r] = nums[r], nums[l]
                l += 1
                r -= 1

        n = len(nums)
        k %= n  # 这里一开始又忘了！导致reverse越界报错
        reverse(0, n-1)
        reverse(0, k-1)
        reverse(k, n-1)

# %%
# 42. 接雨水
# H
# 2 (纠结pre和suf不包含当前位置的做法)

class Solution:
    def trap(self, height: List[int]) -> int:
        # 前后缀 当前位置能接的雨水取决于左侧最高高度和右侧最高高度中较小值
        # Time 12:37
        pre = suf = 0
        ans = 0
        n = len(height)
        l, r = 0, n - 1
        while l < r:
            pre = max(pre, height[l])
            suf = max(suf, height[r])

            if pre < suf:
                ans += pre - height[l]
                l += 1
            else:
                ans += suf - height[r]
                r -= 1
        
        return ans

# 如果pre和suf是不包含当前位置的，

# %%
# 76. 最小覆盖子串
# H
# 3 

class Solution:
    def minWindow(self, s: str, t: str) -> str:
        # 2026-04-09
        # Time 23:00
        diff = defaultdict(int)
        for c in t:
            diff[c] -= 1
        
        kinds = len(set(t))
        ans_left, ans_right = -1, len(s)
        cnt = 0
        l = 0
        for r, c in enumerate(s):
            diff[c] += 1
            if diff[c] == 0:
                cnt += 1
            
            while cnt == kinds:
                if r - l < ans_right - ans_left:
                    ans_left, ans_right = l, r
                
                
                diff[s[l]] -= 1
                
                if diff[s[l]] < 0:
                    cnt -= 1
                
                l += 1

        return "" if ans_left == -1 else s[ans_left:ans_right+1]

# 凌晨写题目真没状态

# %% [markdown]
# # New
