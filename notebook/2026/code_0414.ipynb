# %%
# fast hot100
# 2026-04-14

# %% [markdown]
# # Review

# %%
# 56. 合并区间
# M
#

# %%
# 49. 字母异位词分组
# E
#

# %%
# 206. 反转链表
# E
# 
# 上次备注: 递归解法不熟练

# %%
# 560. 和为 K 的子数组
# M
#

# %%
# 239. 滑动窗口最大值
# H
#

# %%
# 41. 缺失的第一个正数
# H
#

# %%
# 11. 盛最多水的容器
# M
#

# %%
# 1. 两数之和
# E
#

# %%
# 283. 移动零
# E
#

# %%
# 160. 相交链表
# E
#

# %%
# 543. 二叉树的直径
# E
#

# %%
# 108. 将有序数组转换为二叉搜索树
# E
#

# %%
# 128. 最长连续序列
# M
#

# %%
# 73. 矩阵置零
# M
#

# %%
# 102. 二叉树的层序遍历
# M
#

# %%
# 101. 对称二叉树
# E
#

# %%
# 70. 爬楼梯
# E
#

# %%
# 3. 无重复字符的最长子串
# M
#

# %%
# 94. 二叉树的中序遍历
# E
#

# %%
# 76. 最小覆盖子串
# H
#

# %%
# 42. 接雨水
# H
#

# %%
# 104. 二叉树的最大深度
# E
#

# %%
# 226. 翻转二叉树
# E
#

# %%
# 15. 三数之和
# M
#

# %%
# 438. 找到字符串中所有字母异位词
# M
#

# %%
# 53. 最大子数组和
# M
# 
# 上次备注: 易错点：须先更新答案再更新最小前缀

# %%
# 189. 轮转数组
# M
# 
# 上次备注: 翻转数组解法忘记取模

# %%
# 98. 验证二叉搜索树
# M
# 
# 上次备注: 中序遍历解法薄弱

# %%
# 118. 杨辉三角
# E
#

# %%
# 198. 打家劫舍
# M
# 
# 上次备注: O(1)空间解法薄弱

# %% [markdown]
# # New
